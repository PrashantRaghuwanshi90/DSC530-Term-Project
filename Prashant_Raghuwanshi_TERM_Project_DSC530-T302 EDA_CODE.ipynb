# %% [markdown]
# ### Name : Prashant Raghuwanshi
# ### Work:  TERM_Project_DSC530-T302 Data Exploration and Analysis
# ### Date: 08/13/2021

# %%
from __future__ import print_function, division

# %matplotlib inline
import seaborn as sns # vizualisation
import matplotlib.pyplot as plt

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
df = pd.read_csv('C:/Users/dell/Documents/ThinkStats2-master/code/water_potability.csv')

# Show first n rows of data, default is 5
df.head(5).style.set_caption('water_potability Dataset').hide_index().format(None,na_rep="Not Provided")
# Out:
# <style  type="text/css" >
# </style><table id="T_51bad_" ><caption>water_potability Dataset</caption><thead>    <tr>        <th class="col_heading level0 col0" >ph</th>        <th class="col_heading level0 col1" >Hardness</th>        <th class="col_heading level0 col2" >Solids</th>        <th class="col_heading level0 col3" >Chloramines</th>        <th class="col_heading level0 col4" >Sulfate</th>        <th class="col_heading level0 col5" >Conductivity</th>        <th class="col_heading level0 col6" >Organic_carbon</th>        <th class="col_heading level0 col7" >Trihalomethanes</th>        <th class="col_heading level0 col8" >Turbidity</th>        <th class="col_heading level0 col9" >Potability</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_51bad_row0_col0" class="data row0 col0" >Not Provided</td>
#                         <td id="T_51bad_row0_col1" class="data row0 col1" >204.890455</td>
# ...

# %%
df.columns # explore all variables present in the dataset
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df.describe() # find out more insights of provided dataset
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# Details of Variables
# 1. pH value:
#
# PH is an important parameter in evaluating the acid–base balance of water. It is also the indicator of acidic or alkaline condition of water status. WHO has recommended maximum permissible limit of pH from 6.5 to 8.5. The current investigation ranges were 6.52–6.83 which are in the range of WHO standards.
#
# 2. Hardness:
#
# Hardness is mainly caused by calcium and magnesium salts. These salts are dissolved from geologic deposits through which water travels. The length of time water is in contact with hardness producing material helps determine how much hardness there is in raw water. Hardness was originally defined as the capacity of water to precipitate soap caused by Calcium and Magnesium.
#
# 3. Solids (Total dissolved solids - TDS):
#
# Water has the ability to dissolve a wide range of inorganic and some organic minerals or salts such as potassium, calcium, sodium, bicarbonates, chlorides, magnesium, sulfates etc. These minerals produced un-wanted taste and diluted color in appearance of water. This is the important parameter for the use of water. The water with high TDS value indicates that water is highly mineralized. Desirable limit for TDS is 500 mg/l and maximum limit is 1000 mg/l which prescribed for drinking purpose.
#
# 4. Chloramines:
#
# Chlorine and chloramine are the major disinfectants used in public water systems. Chloramines are most commonly formed when ammonia is added to chlorine to treat drinking water. Chlorine levels up to 4 milligrams per liter (mg/L or 4 parts per million (ppm)) are considered safe in drinking water.
#
# 5. Sulfate:
#
# Sulfates are naturally occurring substances that are found in minerals, soil, and rocks. They are present in ambient air, groundwater, plants, and food. The principal commercial use of sulfate is in the chemical industry. Sulfate concentration in seawater is about 2,700 milligrams per liter (mg/L). It ranges from 3 to 30 mg/L in most freshwater supplies, although much higher concentrations (1000 mg/L) are found in some geographic locations.
#
# 6. Conductivity:
#
# Pure water is not a good conductor of electric current rather’s a good insulator. Increase in ions concentration enhances the electrical conductivity of water. Generally, the amount of dissolved solids in water determines the electrical conductivity. Electrical conductivity (EC) actually measures the ionic process of a solution that enables it to transmit current. According to WHO standards, EC value should not exceeded 400 μS/cm.
#
# 7. Organic_carbon:
#
# Total Organic Carbon (TOC) in source waters comes from decaying natural organic matter (NOM) as well as synthetic sources. TOC is a measure of the total amount of carbon in organic compounds in pure water. According to US EPA < 2 mg/L as TOC in treated / drinking water, and < 4 mg/Lit in source water which is use for treatment.
#
# 8. Trihalomethanes:
#
# THMs are chemicals which may be found in water treated with chlorine. The concentration of THMs in drinking water varies according to the level of organic material in the water, the amount of chlorine required to treat the water, and the temperature of the water that is being treated. THM levels up to 80 ppm is considered safe in drinking water.
#
# 9. Turbidity:
#
# The turbidity of water depends on the quantity of solid matter present in the suspended state. It is a measure of light emitting properties of water and the test is used to indicate the quality of waste discharge with respect to colloidal matter. The mean turbidity value obtained for Wondo Genet Campus (0.98 NTU) is lower than the WHO recommended value of 5.00 NTU.
#
# 10. Potability (Target) :
#
# Indicates if water is safe for human consumption where 1 means Potable and 0 means Not potable.

# %%
df.info() # find out the datatype for each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.isnull().sum() # find out the missing values in the dataset's for all variables
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# fixing the missing value by replacing the missed value with correspoding means
df.ph = df.ph.fillna(df.groupby(['Potability'])['ph'].transform('mean'))
df.Sulfate=df.Sulfate.fillna(df.groupby(['Potability'])['Sulfate'].transform('mean'))
df.Trihalomethanes =df.Trihalomethanes.fillna(df.groupby(['Potability'])['Trihalomethanes'].transform('mean'))

# %%
df.isnull().sum() # find out the missing values in the dataset's for all variables after fix
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# Include a histogram of each of the 5 variables

# %%
import thinkplot
import thinkstats2

hist = thinkstats2.Hist(round(df.ph), label='ph_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='ph_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Hardness), label='Hardness_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Hardness_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Solids), label='Solids_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Solids_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Chloramines), label='Chloramines_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Chloramines_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Sulfate), label='Sulfate_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Sulfate_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Trihalomethanes), label='Trihalomethanes_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Trihalomethanes_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist(round(df.Turbidity), label='Turbidity_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Turbidity_Value', ylabel='Count')

# %%
hist = thinkstats2.Hist((df.Potability), label='Potability_Value')
thinkplot.Hist(hist)
thinkplot.Config(xlabel='Potability_Value', ylabel='Count')

# %%
# Now we have seen some values of numerical features are distribute normally but some are not
# Lets use Shapiro test to prove that 
from scipy.stats import shapiro

# H0: Distribution is Normal
# H1: Distribution is not Normal

features = df.iloc[:, 0:-1].columns.to_list()
print(features)
def Shapiro(feature):
        p_value = shapiro(df[feature])[1]
        print(feature, "P_value: = %.5f" % p_value)

for feature in features:
    Shapiro(feature)
# Out:
# ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity', 'Organic_carbon', 'Trihalomethanes', 'Turbidity']
# ph P_value: = 0.00000
# Hardness P_value: = 0.00000
# Solids P_value: = 0.00000
# Chloramines P_value: = 0.00000
# Sulfate P_value: = 0.00000
# Conductivity P_value: = 0.00000
# Organic_carbon P_value: = 0.62103
# Trihalomethanes P_value: = 0.00000
# Turbidity P_value: = 0.93069

# %%
# In the dataset,ph 'Hardness', 'Solids', 'Chloramines' and 'Conductivity' dont distribute normally
# because their p_values which comes from shapiro test are less the 0.05
# and we reject H0: Distribution is Normal

# %%
# Visualization of Outliers
fig, ax = plt.subplots(3,3, figsize = (15,15))
sns.boxplot(df['ph'], ax = ax[0,0])
sns.boxplot(df['Hardness'], ax = ax[0,1])
sns.boxplot(df['Solids'], ax = ax[0,2])
sns.boxplot(df['Chloramines'], ax = ax[1,0])
sns.boxplot(df['Sulfate'], ax = ax[1,1])
sns.boxplot(df['Conductivity'], ax = ax[1,2])
sns.boxplot(df['Organic_carbon'], ax = ax[2,0])
sns.boxplot(df['Trihalomethanes'], ax = ax[2,1])
sns.boxplot(df['Turbidity'], ax = ax[2,2])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
from collections import Counter

#drop the label 
outlier_list = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity','Organic_carbon', 'Trihalomethanes', 'Turbidity'] 

def detect_outlier(df,feature):
    
    outlier_indices = []
    
    for f in feature:
        
        #lower quartile
        q1 = np.percentile(df[f],25)
        
        #upper quartile
        q3 = np.percentile(df[f],75)
        
        #interquartile range
        iqr = q3-q1
        
        #with coefficient
        with_coef = 1.5*iqr
        
        #detect outlier(s)
        lower_rule = q1-with_coef
        upper_rule = q3+with_coef
        
        outlier_variable = df[(df[f]<lower_rule) | (df[f]>upper_rule)].index
        outlier_indices.extend(outlier_variable)
    
    #converting to amount
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i,v in outlier_indices.items() if v>2)
    
    return multiple_outliers

 
#drop outliers
df = df.drop(detect_outlier(df,outlier_list),axis=0).reset_index(drop=True)

# %%
feature_list = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity','Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability']
plt.figure(figsize=(9,3))
sns.heatmap(df[feature_list].corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Using pg. 29 of your text as an example, compare two scenarios in your data using a PMF. Reminder, this isn’t comparing two variables against each other – it is the same variable, but a different scenario. Almost like a filter. The example in the book is first babies compared to all other babies, it is still the same variable, but breaking the data out based on criteria we are exploring (Chapter 3)

# %%
#compare two scenarios in data using a PMF
df_portable = df.loc[df['Potability'] == 1]
df_nonportable = df.loc[df['Potability'] == 0]

# %%
ph_portable_pmf = thinkstats2.Pmf(round(df_portable.ph), label='portable')
ph_nonportable_pmf = thinkstats2.Pmf(round(df_nonportable.ph), label='nonportable')

# %%
width=0.45
axis = [0, 14, 0, 0.5]
thinkplot.PrePlot(2, cols=2)
thinkplot.Hist(ph_portable_pmf, align='right', width=width)
thinkplot.Hist(ph_nonportable_pmf, align='left', width=width)
thinkplot.Config(xlabel='Ph Values -Hist', ylabel='PMF', axis=axis)

thinkplot.PrePlot(2)
thinkplot.SubPlot(2)
thinkplot.Pmfs([ph_portable_pmf, ph_nonportable_pmf])
thinkplot.Config(xlabel='Ph Values-Pmfs', ylabel='PMF', axis=axis)

# %% [markdown]
# Create 1 CDF with one of your variables, using page 41-44 as your guide, what does this tell you about your variable and how does it address the question you are trying to answer (Chapter 4).

# %%
ph_portable_cdf = thinkstats2.Cdf(round(df_portable.ph), label='portable')
ph_nonportable_cdf = thinkstats2.Cdf(round(df_nonportable.ph), label='nonportable')

thinkplot.PrePlot(2)
thinkplot.Cdfs([ph_portable_cdf,ph_nonportable_cdf])
thinkplot.Config(xlabel='Ph Values', ylabel='CDF')

# %% [markdown]
# In this example, we can see that ph values of portable water is slightly, but consistently, less than non portable water.

# %%
import random

def expovariate(lam):
    p = random.random()
    x = -np.log(1-p) / lam
    return x

# %% [markdown]
# Plot 1 analytical distribution and provide your analysis on how it applies to the dataset you have chosen

# %%
diffs = df.ph.diff()
cdf = thinkstats2.Cdf(diffs, label='actual')

n = len(diffs)
lam = 44.0 / 24 / 1
sample = [random.expovariate(lam) for _ in range(n)]

1/lam, np.mean(sample)
# Out:
# (0.5454545454545455, 0.5457148220195909)

# %%
model = thinkstats2.Cdf(sample, label='model')
    
thinkplot.PrePlot(2)
thinkplot.Cdfs([cdf, model], complement=True)
thinkplot.Config(xlabel='difference in Ph values',
                ylabel='CCDF',
                yscale='log')

# %%
# If you plot distributions for a large number of samples, you get a sense
# of how much random variation to expect.  In this case, the data fall within
# the range we expect, so there is no compelling reason to think it is
# not exponential.

for i in range(100):
    sample = [random.expovariate(lam) for _ in range(n)]
    thinkplot.Cdf(thinkstats2.Cdf(sample), complement=True, color='0.9')
    
thinkplot.Cdf(cdf, complement=True)
thinkplot.Config(xlabel='difference in Ph values',
                ylabel='CCDF',
                yscale='log')

# %% [markdown]
# Create two scatter plots comparing two variables and provide your analysis on correlation and causation. Remember, covariance, Pearson’s correlation, and Non-Linear Relationships should also be considered during your analysis

# %%
import pandas as pd

def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

def SpearmanCorr(xs, ys):
    xs = pd.Series(xs)
    ys = pd.Series(ys)
    return xs.corr(ys, method='spearman')

def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov

# %%
phval = df.ph
Hardnessval = df.Hardness
print('Corr', Corr(phval, Hardnessval))
print('SpearmanCorr', SpearmanCorr(phval, Hardnessval))
# Out:
# Corr 0.07408474522774658
# SpearmanCorr 0.10802573231926668

# %%
def ScatterPlot(phval, Hardnessval, alpha=1.0, s=20):
    """Make a scatter plot and save it.

    ages: sequence of float
    weights: sequence of float
    alpha: float
    """
    thinkplot.Scatter(phval, Hardnessval, alpha=alpha)
    thinkplot.Config(xlabel='ph_val',
                     ylabel='Hardness_val',
                     xlim=[0, 14],
                     ylim=[0, 350],
                     legend=False)
    
ScatterPlot(phval, Hardnessval, alpha=0.05, s=10)

# %%
# 1) The scatterplot shows a weak relationship between the variables but
#    it is hard to see clearly.

# 2) The correlations support this.  Pearson's is around 0.07, Spearman's
#    is around 0.1.  The difference between them suggests some influence
#    of outliers or a non-linear relationsip.

# %% [markdown]
# Conduct a test on your hypothesis using one of the methods covered in Chapter 9.

# %% [markdown]
# Permutation test
# To compute the p-value of an observed difference in means, we can assume that there is no difference between the groups and generate simulated results by shuffling the data.

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
data = df_portable.ph, df_nonportable.ph
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.906

# %%
ht.PlotCdf()
thinkplot.Config(xlabel='test statistic',
                   ylabel='CDF')

# %%
# Under the null hypothesis, we often see differences smaller than the observed difference

# %% [markdown]
# For this project, conduct a regression analysis on either one dependent and one explanatory variable, or multiple explanatory variables (Chapter 10 & 11)

# %%
import statsmodels.formula.api as smf

formula = 'Potability ~ Hardness'
model = smf.ols(formula, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Potability   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4591
# Date:                Fri, 13 Aug 2021   Prob (F-statistic):              0.498
# Time:                        03:26:21   Log-Likelihood:                -2287.4
# No. Observations:                3265   AIC:                             4579.
# Df Residuals:                    3263   BIC:                             4591.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4241      0.052      8.134      0.000       0.322       0.526
# ...

# %%
formula = 'Potability ~ Hardness + ph'
results = smf.ols(formula, data=df).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Potability   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.2327
# Date:                Fri, 13 Aug 2021   Prob (F-statistic):              0.792
# Time:                        03:26:21   Log-Likelihood:                -2287.4
# No. Observations:                3265   AIC:                             4581.
# Df Residuals:                    3262   BIC:                             4599.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4271      0.064      6.642      0.000       0.301       0.553
# ...
